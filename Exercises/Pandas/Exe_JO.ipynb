# %%
# 1. Importation de la librairie pandas
import pandas as pd

# 2. Importation du fichier csv
data = pd.read_csv('Exercices_Pandas_athlete_events.csv')

# 3. Afficher les 5 premières lignes afin de voir si l’importation est correct (fonction : head())
display(data.head(5))

# 4. Afficher les 5 dernière lignes (fonction tail())
display(data.tail(5))
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# 5. Afficher les informations sur le dataframe (le nombre de ligne, colonne, le nombre nan, le type de colonne) (méthode info)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
# 6. Afficher les dimensions du dataframe (la méthode shape)
display(data.shape)

# 7. Afficher les statistiques descriptives du dataframe
display(data.describe())
# Out:
# (271116, 15)
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
# 8. Compter le nombre de valeur null dans le dataframe
data.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
# 9. Sélectionner la colonne Edition et afficher (selon 2-3 manières) (Edition=Games)

display(data[['Games']])
display(data.loc[:, ['Games']])
display(data.Games)
data.iloc[0:-1,8]
# Out:
#               Games
# 0       1992 Summer
# 1       2012 Summer
# 2       1920 Summer
# 3       1900 Summer
# 4       1988 Winter
# ...             ...
# 271111  1976 Winter
# 271112  2014 Winter
# 271113  2014 Winter
# 271114  1998 Winter
# 271115  2002 Winter
#
# [271116 rows x 1 columns]
#               Games
# 0       1992 Summer
# 1       2012 Summer
# 2       1920 Summer
# 3       1900 Summer
# 4       1988 Winter
# ...             ...
# 271111  1976 Winter
# 271112  2014 Winter
# 271113  2014 Winter
# 271114  1998 Winter
# 271115  2002 Winter
#
# [271116 rows x 1 columns]
# 0         1992 Summer
# 1         2012 Summer
# 2         1920 Summer
# 3         1900 Summer
# 4         1988 Winter
#              ...
# 271111    1976 Winter
# 271112    2014 Winter
# 271113    2014 Winter
# 271114    1998 Winter
# 271115    2002 Winter
# Name: Games, Length: 271116, dtype: object
# 0         1992 Summer
# 1         2012 Summer
# 2         1920 Summer
# 3         1900 Summer
# ...

# %%
# 10. Sélectionner la colonne Name et afficher le résultat en triant par ordre alphabétique
data['Name']= data['Name'].str.replace(' ', '').str.strip()
data['Name'].sort_values()
# Out:
# 153340    A.AananthaSambuMayavo
# 529               A.AbdulRazzak
# 528               A.AbdulRazzak
# 4015                   A.Albert
# 30535                    A.Brun
#                   ...
# 114965                 zlemKaya
# 79870                 zmanGraud
# 207676                zzetSafer
# 102955                  zzetnce
# 102956                  zzetnce
# Name: Name, Length: 271116, dtype: object

# %%
# 11. Sélectionner les colonnes Event, city, Name, Medal
data.loc[:,['Event','City','Name','Medal']]
# Out:
#                                            Event            City  \
# 0                    Basketball Men's Basketball       Barcelona
# 1                   Judo Men's Extra-Lightweight          London
# 2                        Football Men's Football       Antwerpen
# 3                    Tug-Of-War Men's Tug-Of-War           Paris
# 4               Speed Skating Women's 500 metres         Calgary
# ...                                          ...             ...
# 271111                Luge Mixed (Men)'s Doubles       Innsbruck
# 271112  Ski Jumping Men's Large Hill, Individual           Sochi
# 271113        Ski Jumping Men's Large Hill, Team           Sochi
# 271114                      Bobsleigh Men's Four          Nagano
# 271115                      Bobsleigh Men's Four  Salt Lake City
#
#                           Name Medal
# 0                     ADijiang   NaN
# 1                      ALamusi   NaN
# 2            GunnarNielsenAaby   NaN
# ...

# %%
# 12. Slicer les lignes de 0 à 25 du dataframe au moyen du iloc
data.iloc[0:26,:]
# Out:
#     ID                    Name Sex   Age  Height  Weight            Team  NOC  \
# 0    1                ADijiang   M  24.0   180.0    80.0           China  CHN
# 1    2                 ALamusi   M  23.0   170.0    60.0           China  CHN
# 2    3       GunnarNielsenAaby   M  24.0     NaN     NaN         Denmark  DEN
# 3    4      EdgarLindenauAabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 4    5  ChristineJacobaAaftink   F  21.0   185.0    82.0     Netherlands  NED
# 5    5  ChristineJacobaAaftink   F  21.0   185.0    82.0     Netherlands  NED
# 6    5  ChristineJacobaAaftink   F  25.0   185.0    82.0     Netherlands  NED
# 7    5  ChristineJacobaAaftink   F  25.0   185.0    82.0     Netherlands  NED
# 8    5  ChristineJacobaAaftink   F  27.0   185.0    82.0     Netherlands  NED
# 9    5  ChristineJacobaAaftink   F  27.0   185.0    82.0     Netherlands  NED
# 10   6           PerKnutAaland   M  31.0   188.0    75.0   United States  USA
# ...

# %%
# 13. Filtrer la discipline Football de 2 manières différentes
display(data.loc[data['Sport'] == 'Football'])
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 2            3                GunnarNielsenAaby   M  24.0     NaN     NaN
# 105         37                 AnnKristinAarnes   F  23.0   182.0    64.0
# 116         41                          RolfAas   M  28.0     NaN     NaN
# 157         61                  StefanAbadzhiev   M  26.0   175.0    72.0
# 178         76          JouanPatriceAbandaEtong   M  22.0   185.0    82.0
# ...        ...                              ...  ..   ...     ...     ...
# 270810  135438               ManuelZigaFernndez   M  20.0   172.0    69.0
# 270843  135455                   Vjekoslavupani   M  19.0     NaN     NaN
# 270901  135476                  EmilyJaneZurrer   F  21.0   179.0    69.0
# 270982  135504  ViktorOleksandrovychZviahintsev   M  25.0   178.0    79.0
# 271107  135566          JamesFrancis"Jim"Zylker   M  21.0   175.0    75.0
#
#                  Team  NOC        Games  Year  Season       City     Sport  \
# ...

# %%
# 14. Filtrer le dataframe sur la saison Summer et stocker les lignes dans une nouvelle variable appelée « ete »
summer = data[data['Season'] == 'Summer']
summer
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 0            1                         ADijiang   M  24.0   180.0    80.0
# 1            2                          ALamusi   M  23.0   170.0    60.0
# 2            3                GunnarNielsenAaby   M  24.0     NaN     NaN
# 3            4               EdgarLindenauAabye   M  34.0     NaN     NaN
# 26           8  Cornelia"Cor"Aalten(-Strannood)   F  18.0   168.0     NaN
# ...        ...                              ...  ..   ...     ...     ...
# 271106  135565           FernandoscarZylberberg   M  27.0   168.0    76.0
# 271107  135566          JamesFrancis"Jim"Zylker   M  21.0   175.0    75.0
# 271108  135567       AleksandrViktorovichZyuzin   M  24.0   183.0    72.0
# 271109  135567       AleksandrViktorovichZyuzin   M  28.0   183.0    72.0
# 271110  135568             OlgaIgorevnaZyuzkova   F  33.0   171.0    69.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
# 15. Filtrer le dataframe sur la saison Winter et stocker les lignes dans une nouvelle variable appelée « hiver »
winter = data[data['Season'] == 'Winter']
winter
# Out:
#             ID                    Name Sex   Age  Height  Weight         Team  \
# 4            5  ChristineJacobaAaftink   F  21.0   185.0    82.0  Netherlands
# 5            5  ChristineJacobaAaftink   F  21.0   185.0    82.0  Netherlands
# 6            5  ChristineJacobaAaftink   F  25.0   185.0    82.0  Netherlands
# 7            5  ChristineJacobaAaftink   F  25.0   185.0    82.0  Netherlands
# 8            5  ChristineJacobaAaftink   F  27.0   185.0    82.0  Netherlands
# ...        ...                     ...  ..   ...     ...     ...          ...
# 271111  135569               Andrzejya   M  29.0   179.0    89.0     Poland-1
# 271112  135570                 Piotrya   M  27.0   176.0    59.0       Poland
# 271113  135570                 Piotrya   M  27.0   176.0    59.0       Poland
# 271114  135571        TomaszIreneuszya   M  30.0   185.0    96.0       Poland
# 271115  135571        TomaszIreneuszya   M  34.0   185.0    96.0       Poland
#
# ...

# %%
# 16. Afficher de manière unique tous les sports
data['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
# 17. Filtrer les lignes pour récupérer les athlètes ayant dans leur nom « Owens » ou « Jesse » et stocker cela dans une nouvelle variable
jesse_owens = data[(data['Name'].str.contains('Jesse')) | (data['Name'].str.contains('Owens'))]
jesse_owens
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 14038     7587   KennethOwens"Ken"Bantum   M  21.0   198.0   106.0
# 35531    18266  JesseLandis"Lee"Carleton   M  41.0     NaN     NaN
# 35532    18266  JesseLandis"Lee"Carleton   M  41.0     NaN     NaN
# 43016    22182              JesseCockney   M  24.0   180.0    76.0
# 43017    22182              JesseCockney   M  24.0   180.0    76.0
# ...        ...                       ...  ..   ...     ...     ...
# 256091  128225    JesseAlfredWallingford   M  36.0     NaN     NaN
# 256092  128225    JesseAlfredWallingford   M  36.0     NaN     NaN
# 260999  130612       JesseDanielWilliams   M  24.0   184.0    80.0
# 261000  130612       JesseDanielWilliams   M  28.0   184.0    80.0
# 262755  131475           HarveyJesseWood   M  23.0   193.0    89.0
#
#                                     Team  NOC        Games  Year  Season  \
# 14038                      United States  USA  1956 Summer  1956  Summer
# ...

# %%
# 17. Compter les occurrences de la colonne Event de Owens, Jesse (fonction value_counts())
data[(data['Name'].str.contains('Jesse')) & (data['Name'].str.contains('Owens'))]
# Out:
#            ID                        Name Sex   Age  Height  Weight  \
# 179557  90226  JamesCleveland"Jesse"Owens   M  22.0   178.0    71.0
# 179558  90226  JamesCleveland"Jesse"Owens   M  22.0   178.0    71.0
# 179559  90226  JamesCleveland"Jesse"Owens   M  22.0   178.0    71.0
# 179560  90226  JamesCleveland"Jesse"Owens   M  22.0   178.0    71.0
#
#                  Team  NOC        Games  Year  Season    City      Sport  \
# 179557  United States  USA  1936 Summer  1936  Summer  Berlin  Athletics
# 179558  United States  USA  1936 Summer  1936  Summer  Berlin  Athletics
# 179559  United States  USA  1936 Summer  1936  Summer  Berlin  Athletics
# 179560  United States  USA  1936 Summer  1936  Summer  Berlin  Athletics
#
#                                        Event Medal
# 179557            Athletics Men's 100 metres  Gold
# 179558            Athletics Men's 200 metres  Gold
# 179559  Athletics Men's 4 x 100 metres Relay  Gold
# 179560             Athletics Men's Long Jump  Gold

# %%
# 18. Compter y a-t-il de femme est d’homme dans le dataframe (fonction value_counts())
data['Sex'].value_counts()
# Out:
# Sex
# M    196594
# F     74522
# Name: count, dtype: int64

# %%
# 19. Quel est l’athlète le plus jeune
display(data[data['Age'] == data['Age'].min()])

# 20. Quel est l’athlète le plus vieux
display(data[data['Age'] == data['Age'].max()])
# Out:
#            ID               Name Sex   Age  Height  Weight  \
# 142882  71691  DimitriosLoundras   M  10.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season    City  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer  Athina
#
#              Sport                                  Event   Medal
# 142882  Gymnastics  Gymnastics Men's Parallel Bars, Teams  Bronze
#             ID                 Name Sex   Age  Height  Weight           Team  \
# 257054  128719  JohnQuincyAdamsWard   M  97.0     NaN     NaN  United States
#
#         NOC        Games  Year  Season       City             Sport  \
# 257054  USA  1928 Summer  1928  Summer  Amsterdam  Art Competitions
#
#                                               Event Medal
# 257054  Art Competitions Mixed Sculpturing, Statues   NaN

# %%
# 22. Quels sont les joueurs ayant gagné des médailles d’Or en badminton simple au cours des années. Trier le résultat par ordre alphabétique sur le nom des joueurs.

gold_badminton_singles = data[(data['Sport'] == 'Badminton') & (data['Event'].str.contains('Singles')) & (data['Medal'] == 'Gold')]

gold_badminton_singles.sort_values('Name')
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 31409    16152      AlexanderAlanBudikusumaWiratama   M  24.0   178.0    71.0
# 13855     7504                         BangSu-Hyeon   F  23.0     NaN     NaN
# 149622   75045                 CarolinaMaraMarnMarn   F  23.0   172.0    65.0
# 39337    20238                             ChenLong   M  27.0   188.0    81.0
# 81604    41427                          GongZhichao   F  23.0   163.0    52.0
# 108331   54755                            JiXinpeng   M  22.0   181.0    70.0
# 138456   69540                             LiXuerui   F  21.0   175.0    65.0
# 139311   69968                               LinDan   M  24.0   177.0    70.0
# 139312   69968                               LinDan   M  28.0   177.0    70.0
# 232573  116659  LuciaFrancisca"Susi"SusantiHaditono   F  21.0   161.0     NaN
# 99666    50431      Poul-ErikHyerLarsen(-EngelHyer)   M  30.0   188.0    79.0
# ...

# %%
# 23. Quels sont les 3 pays ayant gagné le plus de médailles de 1984 à 2016

medals = data[(data['Medal'] == 'Gold') | (data['Medal'] == 'Silver') | (data['Medal'] == 'Bronze')]
period = medals[(medals['Year'] > 1984) & (medals['Year'] < 2016)]

countries = period['Team'].value_counts()

countries.head(3)
# Out:
# Team
# United States    2057
# Germany          1028
# Russia            987
# Name: count, dtype: int64

# %%
# 24. Combien y a-t-il d’homme et de femme ayant participé aux Jeux olympiques d’été en 2016
summer_games_2016 = data[(data['Season'] == 'Summer') & (data['Year'] == 2016)]
display(summer_games_2016)

# Trier par personne (id) (enlever duplicates)
data_without_duplicates = summer_games_2016.drop_duplicates(subset=['ID'])
display(data_without_duplicates)

# Compter le nombre H et F
data_without_duplicates['Sex'].value_counts()
# Out:
#             ID                         Name Sex   Age  Height  Weight  \
# 80          22                 AndreeaAanei   F  22.0   170.0   125.0
# 139         51              NstorAbadSanjun   M  23.0   167.0    64.0
# 140         51              NstorAbadSanjun   M  23.0   167.0    64.0
# 141         51              NstorAbadSanjun   M  23.0   167.0    64.0
# 142         51              NstorAbadSanjun   M  23.0   167.0    64.0
# ...        ...                          ...  ..   ...     ...     ...
# 271024  135528                 MarcZwiebler   M  32.0   181.0    75.0
# 271053  135547  ViktoriyaViktorovnaZyabkina   F  23.0   174.0    62.0
# 271054  135547  ViktoriyaViktorovnaZyabkina   F  23.0   174.0    62.0
# 271055  135547  ViktoriyaViktorovnaZyabkina   F  23.0   174.0    62.0
# 271110  135568         OlgaIgorevnaZyuzkova   F  33.0   171.0    69.0
#
#               Team  NOC        Games  Year  Season            City  \
# ...

# %%
# 25. Afficher le nombre de médailles pour la Belgique
team_be = data[data['Team'] == 'Belgium']

medaled_team_be = team_be[(team_be['Medal'] == 'Gold') | (team_be['Medal'] == 'Silver') | (team_be['Medal'] == 'Bronze')]

# display(medaled_team_be['Medal'].count())
medaled_team_be['Medal'].value_counts()
# Out:
# Medal
# Silver    161
# Bronze    154
# Gold       94
# Name: count, dtype: int64

# %%
# 26. Quels sont les sports pour lesquels la Belgique a des médailles d’Or
gold = medaled_team_be[medaled_team_be['Medal'] == 'Gold']
# display(gold['Sport'].count())
gold['Sport'].value_counts()
# Out:
# Sport
# Archery             35
# Football            14
# Cycling             13
# Fencing             10
# Equestrianism        6
# Athletics            4
# Figure Skating       2
# Judo                 2
# Art Competitions     2
# Weightlifting        1
# Swimming             1
# Boxing               1
# Tennis               1
# Sailing              1
# Shooting             1
# Name: count, dtype: int64

# %%
#
